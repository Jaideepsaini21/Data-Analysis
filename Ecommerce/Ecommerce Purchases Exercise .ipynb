# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("Ecommerce Purchases.csv")
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **Check the head of the DataFrame.**

# %% [markdown]
# ** How many rows and columns are there? **

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  float64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
sum(data['Purchase Price'])
# Out:
# 503473.02000000246

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
data[data['Language']=='en']
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
len(data[data['Language']=='en'])
# Out:
# 1098

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
data[data['Job']=='Lawyer']
# Out:
#                                                 Address    Lot AM or PM  \
# 470   9310 Bailey Mountain Apt. 832\nLake Jacqueline...  67 tQ       PM
# 508     5064 Nicole Circle\nJohnsonburgh, NM 78266-6283  53 rJ       PM
# 1275  4394 Sherry Row Suite 034\nSouth Rebecca, MD 6...  80 jP       PM
# 1569  91733 King Mountains Apt. 356\nSouth Tammy, NE...  20 Aa       AM
# 1682      5691 Fox Mountains\nDudleyside, GU 66765-2101  67 Bk       AM
# 2164  57897 Stacey Pass\nLake Jacquelinestad, MA 038...  61 DY       PM
# 2619   720 Laurie Plains Apt. 458\nChavezfurt, DE 05290  38 gp       AM
# 2935         816 Cheyenne Causeway\nHeidibury, FL 10365  70 nu       AM
# 3663       6218 Mendez Estate\nEast Kylemouth, MI 80812  63 BG       PM
# 3738   3921 Courtney River\nSouth Donaldmouth, AK 78115  85 Rh       AM
# 3966  3465 Hunter Streets Apt. 976\nMedinachester, W...  07 xf       PM
# 5053       88431 Thomas Stream\nMartinchester, WA 82488  19 fZ       PM
# ...

# %%
data[(data['Job'] == "Lawyer")].__len__() => 30
# Out:
#   Cell In[9], line 1
#     data[(data['Job'] == "Lawyer")].__len__() => 30
#     ^
# SyntaxError: cannot assign to function call

# %%
len(data[data['Job']=='Lawyer'])

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
data['AM or PM'].value_counts()

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
data[data['Lot']=='90 WT']['Purchase Price']

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
email=data[data['Credit Card']==4926535242672853]

# %%
email

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
data[(data['CC Provider'] =='American Express') & (data['Purchase Price']<95)]

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
(data['CC Exp Date'].apply(lambda x:x.split("/")[-1] == '25'))

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
data['Email'].apply(lambda x:x.split("@")[-1]).value_counts(5)

# %% [markdown]
# # Which of the sum of Purchase price in AM ?

# %%
data[(data['AM or PM']=='AM')].sum()['Purchase Price']

# %% [markdown]
# # Which of the sum of Purchase price in PM ?

# %%
data[(data['AM or PM']=='PM')].sum()['Purchase Price']

# %%
data['AM or PM'].value_counts()

# %%
data[data['AM or PM'] =='AM']['Purchase Price'].sum()

# %%
data[data['AM or PM'] =='PM']['Purchase Price'].sum()

# %%
data.groupby('AM or PM').count()

# %%
data.groupby('AM or PM')['Purchase Price'].sum()

# %% [markdown]
# # Which of the mean of all purchase price in a cc provider

# %%
data.groupby('CC Provider')['Purchase Price'].mean()

# %% [markdown]
# # Which of the value_count of AM And PM  in a cc provider ?

# %%
data.groupby('CC Provider')['AM or PM'].value_counts()

# %%
data[data['Email'].apply(lambda x:x.split('@')[-1])=='gmail.com']['CC Security Code']

# %% [markdown]
# # Great Job!

# %% [markdown]
# # ip address concept Ques.

# %%
data['IP Address']
# Out:
# 0       149.146.147.205
# 1          15.160.41.51
# 2        132.207.160.22
# 3          30.250.74.19
# 4          24.140.33.94
#              ...
# 9995      29.73.197.114
# 9996     121.133.168.51
# 9997      156.210.0.254
# 9998       55.78.26.143
# 9999    176.119.198.199
# Name: IP Address, Length: 10000, dtype: object

# %%
data[data['IP Address'].apply(lambda x: True if int(x.split('.')[0])<=126 else False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
b = data[data['IP Address'].apply(lambda x:True if 127<=int(x.split('.')[0])<=191 else False)]
b
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...                                                 ...    ...      ...
# 9988      0154 Green Forest\nNew Timothy, IL 33670-4620  11 MC       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
c = data[data['IP Address'].apply(lambda x:True if 192<=int(x.split('.')[0])<=223 else False)]
c
# Out:
#                                                 Address    Lot AM or PM  \
# 17    950 Jacqueline Village Apt. 592\nPort Kimberly...  23 Rh       PM
# 29    30755 Joshua Plaza Apt. 567\nWest Susanton, FM...  93 OP       PM
# 30      849 Tony Unions Apt. 654\nSnowchester, SD 66068  76 zr       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# ...                                                 ...    ...      ...
# 9905  6432 Romero Squares Apt. 655\nPort Emilyburgh,...  40 AU       PM
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9962  223 Tiffany Gardens Suite 056\nJohnnyshire, MP...  33 hQ       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
#
#                                            Browser Info  \
# ...

# %%
d = data[data['IP Address'].apply(lambda x:True if 224<=int(x.split('.')[0])<=239 else False)]
d

# %%
e = data[data['IP Address'].apply(lambda x:True if 240<=int(x.split('.')[0])<=255 else False)]
e
