# %% [markdown]
# #### `Analyse play store dataset and write down conclusion of the analysis and also create plots if possible.`

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("googleplaystore.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## que1 :- Which category of apps has big count ?

# %%
data['Category'].value_counts().head(1)
# Out:
# Category
# FAMILY    1972
# Name: count, dtype: int64

# %% [markdown]
# ## que2 :- Top 5 Highest rating app from each category?

# %%
# lis = []
# lis.append(data.groupby('Category')['Rating'].nlargest(5))
# lis
# data.groupby('Category')['Rating', 'App'].nlargest(5, 'Rating')
data.groupby('Category').apply(lambda x: x.nlargest(5, 'Rating')).reset_index(drop=True).head()
# Out:
#                                                  App        Category  Rating  \
# 0            Life Made WI-Fi Touchscreen Photo Frame             1.9    19.0
# 1            Spring flowers theme couleurs d t space  ART_AND_DESIGN     5.0
# 2                         Harley Quinn wallpapers HD  ART_AND_DESIGN     4.8
# 3                                  Cardi B Wallpaper  ART_AND_DESIGN     4.8
# 4  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN     4.8
#
#   Reviews    Size Installs  Type     Price Content Rating             Genres  \
# 0    3.0M  1,000+     Free     0  Everyone            NaN  February 11, 2018
# 1       1    2.9M     100+  Free         0       Everyone       Art & Design
# 2     192    6.0M  10,000+  Free         0       Everyone       Art & Design
# 3     253    3.7M  50,000+  Free         0       Everyone       Art & Design
# 4    1216    8.6M  10,000+  Paid     $1.99       Everyone       Art & Design
#
# ...

# %% [markdown]
# ## que3 :- Find number of free and paid apps.

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# ## que4 :- Number of highest rating apps?

# %%
# data['Rating'].value_counts().head(1)
data['Rating'].max()
# Out:
# 19.0

# %% [markdown]
# ## que5 :- Find the Category & ratings of apps which are paid.

# %%
data[['Category','Rating']]

# pa = data[data['Type'] == 'Paid']
# p = pa[['Category', 'Rating']]
# p
# Out:
#                   Category  Rating
# 0           ART_AND_DESIGN     4.1
# 1           ART_AND_DESIGN     3.9
# 2           ART_AND_DESIGN     4.7
# 3           ART_AND_DESIGN     4.5
# 4           ART_AND_DESIGN     4.3
# ...                    ...     ...
# 10836               FAMILY     4.5
# 10837               FAMILY     5.0
# 10838              MEDICAL     NaN
# 10839  BOOKS_AND_REFERENCE     4.5
# 10840            LIFESTYLE     4.5
#
# [10841 rows x 2 columns]

# %% [markdown]
# ## que 6 :- Find the name of the apps which has installed >500,000 and rating >=4.0

# %%
data[(data['Installs']>500000+) and (data['Rating']>=4.0)]
# Out:
#   Cell In[20], line 1
#     data[(data['Installs']>500000+) and (data['Rating']>=4.0)]
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## create your own question and solve them here.

# %%
data['Genres'].apply(lambda x : x.split(';')).explode().value_counts().head(10)
# Out:
# Genres
# Tools              843
# Education          761
# Entertainment      667
# Medical            463
# Business           460
# Productivity       424
# Sports             402
# Personalization    392
# Communication      388
# Lifestyle          383
# Name: count, dtype: int64

# %% [markdown]
# # How many the unique categories available in the dataset?

# %%
data['Category'].nunique()
# Out:
# 34

# %% [markdown]
# # Which category has the highest number of apps?

# %%
data['Category'].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %% [markdown]
# # What is the average rating for each category?

# %%
data.groupby('Category')['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %% [markdown]
# # What are correlations between ratings and  installs?

# %%
data[['Rating', 'Genres']].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data[['Rating', 'Genres']].corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # Which categories have the highest average number of installations?

# %%
data.groupby('Category')['Installs'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
data
# Out:
#       App             Category  Rating Reviews                Size  \
# 0       0       ART_AND_DESIGN     4.1     159                 19M
# 1       0       ART_AND_DESIGN     3.9     967                 14M
# 2       0       ART_AND_DESIGN     4.7   87510                8.7M
# 3       0       ART_AND_DESIGN     4.5  215644                 25M
# 4       0       ART_AND_DESIGN     4.3     967                2.8M
# ...    ..                  ...     ...     ...                 ...
# 10836   0               FAMILY     4.5      38                 53M
# 10837   0               FAMILY     5.0       4                3.6M
# 10838   0              MEDICAL     NaN       3                9.5M
# 10839   0  BOOKS_AND_REFERENCE     4.5     114  Varies with device
# 10840   0            LIFESTYLE     4.5  398307                 19M
#
#           Installs  Type Price Content Rating                     Genres  \
# 0          10,000+  Free     0       Everyone               Art & Design
# ...

# %% [markdown]
# # What is the distribution of app prices?

# %%
data[data["Type"]=="Paid"]["Price"]
# Out:
# 234       $4.99
# 235       $4.99
# 290       $4.99
# 291       $4.99
# 427       $3.99
#           ...
# 10735     $0.99
# 10760     $7.99
# 10782    $16.99
# 10785     $1.20
# 10798     $1.04
# Name: Price, Length: 800, dtype: object

# %% [markdown]
# # Is there a correlation between the size of an app and its rating or number of installations?

# %%
data[['Size','Rating']]
# Out:
#                      Size  Rating
# 0                     19M     4.1
# 1                     14M     3.9
# 2                    8.7M     4.7
# 3                     25M     4.5
# 4                    2.8M     4.3
# ...                   ...     ...
# 10836                 53M     4.5
# 10837                3.6M     5.0
# 10838                9.5M     NaN
# 10839  Varies with device     4.5
# 10840                 19M     4.5
#
# [10841 rows x 2 columns]

# %%
data[['Size','Rating']].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data[['Size','Rating']].corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # What is the average rating and number of installations for apps developed by the top developers?

# %%
data['Developer'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Developer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...

# %% [markdown]
# ## Top  contain rating

# %%
data['Content Rating']
# Out:
# Content Rating
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %% [markdown]
# # find the top 3 most expensive apps that have a rating 4.5 ?

# %%
data[data.loc[::,'Rating']>4.5]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...
